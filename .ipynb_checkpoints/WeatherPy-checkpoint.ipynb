# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1550)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1550)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q= + {city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | chinde
# City not found. Skipping...
# Processing Record 3 of Set 1 | kannavam
# City not found. Skipping...
# Processing Record 4 of Set 1 | invercargill
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | madaoua
# Processing Record 7 of Set 1 | port mathurin
# Processing Record 8 of Set 1 | nuku'alofa
# City not found. Skipping...
# Processing Record 9 of Set 1 | tindouf
# Processing Record 10 of Set 1 | lorengau
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | aykhal
# Processing Record 13 of Set 1 | matoury
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | papatowai
# City not found. Skipping...
# Processing Record 18 of Set 1 | noumea
# Processing Record 19 of Set 1 | margaret river
# Processing Record 20 of Set 1 | susuman
# Processing Record 21 of Set 1 | bima
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | staroyur'yevo
# City not found. Skipping...
# Processing Record 26 of Set 1 | kerikeri
# Processing Record 27 of Set 1 | wafangdian
# Processing Record 28 of Set 1 | yuzhno-kurilsk
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | isafjordur
# City not found. Skipping...
# Processing Record 32 of Set 1 | el calafate
# Processing Record 33 of Set 1 | chegdomyn
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | amga
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | coquimbo
# Processing Record 38 of Set 1 | siguiri
# Processing Record 39 of Set 1 | kudahuvadhoo
# Processing Record 40 of Set 1 | ronneby
# Processing Record 41 of Set 1 | mermoz boabab
# Processing Record 42 of Set 1 | anadyr
# Processing Record 43 of Set 1 | kalat
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | stanley
# Processing Record 46 of Set 1 | kuanda
# Processing Record 47 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 48 of Set 1 | sisimiut
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | torghay
# Processing Record 0 of Set 2 | bilibino
# Processing Record 1 of Set 2 | hawaiian paradise park
# Processing Record 2 of Set 2 | gadzhiyevo
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | bamyan
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | blackmans bay
# Processing Record 8 of Set 2 | bilozerka
# Processing Record 9 of Set 2 | nova vicosa
# Processing Record 10 of Set 2 | qusmuryn
# Processing Record 11 of Set 2 | san casciano in val di pesa
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | aasiaat
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | portland
# Processing Record 17 of Set 2 | prince rupert
# Processing Record 18 of Set 2 | puerto natales
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | tazacorte
# Processing Record 21 of Set 2 | carutapera
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | la passe
# City not found. Skipping...
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | nagqu
# Processing Record 26 of Set 2 | weno
# City not found. Skipping...
# Processing Record 27 of Set 2 | selfoss
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | old town
# Processing Record 30 of Set 2 | lodwar
# Processing Record 31 of Set 2 | eastham
# Processing Record 32 of Set 2 | fannuj
# City not found. Skipping...
# Processing Record 33 of Set 2 | kidal
# Processing Record 34 of Set 2 | liberal
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | codrington
# Processing Record 38 of Set 2 | gargalianoi
# Processing Record 39 of Set 2 | sharlyk
# Processing Record 40 of Set 2 | ixtapa
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | kavaratti
# Processing Record 43 of Set 2 | pandan
# Processing Record 44 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 2 | wailua homesteads
# Processing Record 46 of Set 2 | shar
# Processing Record 47 of Set 2 | jinchang
# Processing Record 48 of Set 2 | vrangel'
# City not found. Skipping...
# Processing Record 49 of Set 2 | okha
# Processing Record 0 of Set 3 | badger
# Processing Record 1 of Set 3 | westport
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | bayanhongor
# Processing Record 4 of Set 3 | sur
# Processing Record 5 of Set 3 | kill devil hills
# Processing Record 6 of Set 3 | abalak
# Processing Record 7 of Set 3 | port macquarie
# Processing Record 8 of Set 3 | yung shue wan
# Processing Record 9 of Set 3 | puerto baquerizo moreno
# Processing Record 10 of Set 3 | magdagachi
# Processing Record 11 of Set 3 | simod
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | tual
# Processing Record 14 of Set 3 | medicine hat
# Processing Record 15 of Set 3 | labytnangi
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | olonkinbyen
# Processing Record 18 of Set 3 | utrik
# Processing Record 19 of Set 3 | kolonia
# Processing Record 20 of Set 3 | west island
# Processing Record 21 of Set 3 | peace river
# Processing Record 22 of Set 3 | conduaga
# Processing Record 23 of Set 3 | taroa
# Processing Record 24 of Set 3 | tanjung selor
# City not found. Skipping...
# Processing Record 25 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 26 of Set 3 | tralee
# Processing Record 27 of Set 3 | queenstown
# Processing Record 28 of Set 3 | kharagpur
# Processing Record 29 of Set 3 | kabalo
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | daru
# Processing Record 33 of Set 3 | pacific grove
# Processing Record 34 of Set 3 | oltinko'l
# City not found. Skipping...
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | klyuchi
# Processing Record 37 of Set 3 | hermanus
# Processing Record 38 of Set 3 | chota
# Processing Record 39 of Set 3 | enewetak
# Processing Record 40 of Set 3 | novyy turtkul'
# City not found. Skipping...
# Processing Record 41 of Set 3 | nova sintra
# City not found. Skipping...
# Processing Record 42 of Set 3 | udachny
# City not found. Skipping...
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | egilsstadir
# Processing Record 45 of Set 3 | pirna
# Processing Record 46 of Set 3 | nyurba
# Processing Record 47 of Set 3 | alice springs
# Processing Record 48 of Set 3 | mendefera
# Processing Record 49 of Set 3 | edinburgh of the seven seas
# Processing Record 0 of Set 4 | nogliki
# Processing Record 1 of Set 4 | raymondville
# Processing Record 2 of Set 4 | fort st. john
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | rawson
# Processing Record 5 of Set 4 | whitehorse
# Processing Record 6 of Set 4 | cristalina
# Processing Record 7 of Set 4 | caucete
# Processing Record 8 of Set 4 | port saint john's
# City not found. Skipping...
# Processing Record 9 of Set 4 | port hedland
# Processing Record 10 of Set 4 | carauari
# Processing Record 11 of Set 4 | vorgashor
# Processing Record 12 of Set 4 | jindabyne
# Processing Record 13 of Set 4 | illizi
# Processing Record 14 of Set 4 | howard springs
# City not found. Skipping...
# Processing Record 15 of Set 4 | kone
# Processing Record 16 of Set 4 | idri
# Processing Record 17 of Set 4 | nuuk
# Processing Record 18 of Set 4 | al kharijah
# Processing Record 19 of Set 4 | brokopondo
# Processing Record 20 of Set 4 | mahina
# Processing Record 21 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 4 | lihue
# Processing Record 23 of Set 4 | eyl
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | broome
# Processing Record 26 of Set 4 | bayt al faqih
# Processing Record 27 of Set 4 | saint-leu
# Processing Record 28 of Set 4 | rovaniemi
# Processing Record 29 of Set 4 | vilyuchinsk
# Processing Record 30 of Set 4 | urengoy
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | ust-nera
# Processing Record 33 of Set 4 | griffith
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | necochea
# Processing Record 36 of Set 4 | iskateley
# Processing Record 37 of Set 4 | tazovsky
# City not found. Skipping...
# Processing Record 38 of Set 4 | cannonvale
# Processing Record 39 of Set 4 | paphos
# Processing Record 40 of Set 4 | vadso
# Processing Record 41 of Set 4 | nar'yan-mar
# City not found. Skipping...
# Processing Record 42 of Set 4 | santana
# Processing Record 43 of Set 4 | saipan
# Processing Record 44 of Set 4 | atafu village
# Processing Record 45 of Set 4 | sibolga
# Processing Record 46 of Set 4 | marquette
# Processing Record 47 of Set 4 | mount gambier
# Processing Record 48 of Set 4 | tamanrasset
# Processing Record 49 of Set 4 | tchintabaraden
# City not found. Skipping...
# Processing Record 0 of Set 5 | poronaysk
# Processing Record 1 of Set 5 | newman
# Processing Record 2 of Set 5 | quepos
# Processing Record 3 of Set 5 | venosa
# Processing Record 4 of Set 5 | pahrump
# Processing Record 5 of Set 5 | xingcheng
# Processing Record 6 of Set 5 | fort bragg
# Processing Record 7 of Set 5 | north bend
# Processing Record 8 of Set 5 | kapuskasing
# Processing Record 9 of Set 5 | porto novo
# Processing Record 10 of Set 5 | acapulco de juarez
# Processing Record 11 of Set 5 | tomah
# Processing Record 12 of Set 5 | yonan-up
# Processing Record 13 of Set 5 | vado ligure
# Processing Record 14 of Set 5 | carupano
# Processing Record 15 of Set 5 | dunedin
# Processing Record 16 of Set 5 | ghadamis
# Processing Record 17 of Set 5 | le port
# Processing Record 18 of Set 5 | valparaiso
# Processing Record 19 of Set 5 | cuichapa
# Processing Record 20 of Set 5 | vorkuta
# Processing Record 21 of Set 5 | nicoya
# Processing Record 22 of Set 5 | el nido
# Processing Record 23 of Set 5 | buala
# Processing Record 24 of Set 5 | kachug
# Processing Record 25 of Set 5 | piton saint-leu
# Processing Record 26 of Set 5 | keflavik
# Processing Record 27 of Set 5 | san juan bautista
# Processing Record 28 of Set 5 | llallagua
# Processing Record 29 of Set 5 | melipilla
# Processing Record 30 of Set 5 | bizerte
# Processing Record 31 of Set 5 | baukau
# City not found. Skipping...
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | konarka
# Processing Record 34 of Set 5 | saint-jean-de-monts
# Processing Record 35 of Set 5 | waingapu
# Processing Record 36 of Set 5 | napili-honokowai
# Processing Record 37 of Set 5 | reggane
# Processing Record 38 of Set 5 | totskoye
# Processing Record 39 of Set 5 | polyarnyy
# Processing Record 40 of Set 5 | ambovombe
# Processing Record 41 of Set 5 | yemetsk
# Processing Record 42 of Set 5 | ola
# Processing Record 43 of Set 5 | ayios konstandinos
# City not found. Skipping...
# Processing Record 44 of Set 5 | raduzhny
# City not found. Skipping...
# Processing Record 45 of Set 5 | tandil
# Processing Record 46 of Set 5 | vuktyl
# Processing Record 47 of Set 5 | gandorhun
# Processing Record 48 of Set 5 | lafia
# Processing Record 49 of Set 5 | banamba
# Processing Record 0 of Set 6 | temiskaming shores
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | nadvoitsy
# Processing Record 3 of Set 6 | yangambi
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | najran
# Processing Record 6 of Set 6 | loukhi
# Processing Record 7 of Set 6 | fort mcmurray
# Processing Record 8 of Set 6 | zouerate
# Processing Record 9 of Set 6 | st. john's
# City not found. Skipping...
# Processing Record 10 of Set 6 | mount isa
# Processing Record 11 of Set 6 | okhotsk
# Processing Record 12 of Set 6 | kununurra
# Processing Record 13 of Set 6 | mitu
# Processing Record 14 of Set 6 | nyaunglebin
# Processing Record 15 of Set 6 | murzuq
# Processing Record 16 of Set 6 | niafunke
# City not found. Skipping...
# Processing Record 17 of Set 6 | bodo
# Processing Record 18 of Set 6 | constantia
# Processing Record 19 of Set 6 | thunder bay
# Processing Record 20 of Set 6 | gizo
# Processing Record 21 of Set 6 | auki
# Processing Record 22 of Set 6 | ribeira grande
# Processing Record 23 of Set 6 | batticaloa
# Processing Record 24 of Set 6 | port isabel
# Processing Record 25 of Set 6 | brookings
# Processing Record 26 of Set 6 | san rafael del sur
# Processing Record 27 of Set 6 | alesund
# Processing Record 28 of Set 6 | guatire
# Processing Record 29 of Set 6 | ouled mimoun
# Processing Record 30 of Set 6 | vysokovsk
# Processing Record 31 of Set 6 | tari
# City not found. Skipping...
# Processing Record 32 of Set 6 | wotje
# Processing Record 33 of Set 6 | rakops
# Processing Record 34 of Set 6 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 6 | punta arenas
# Processing Record 36 of Set 6 | port douglas
# Processing Record 37 of Set 6 | malangali
# Processing Record 38 of Set 6 | ciudad lazaro cardenas
# City not found. Skipping...
# Processing Record 39 of Set 6 | shima
# Processing Record 40 of Set 6 | smolensk
# Processing Record 41 of Set 6 | fonadhoo
# City not found. Skipping...
# Processing Record 42 of Set 6 | tadif
# Processing Record 43 of Set 6 | qarauyl
# Processing Record 44 of Set 6 | gyeongju
# City not found. Skipping...
# Processing Record 45 of Set 6 | torit
# Processing Record 46 of Set 6 | oppdal
# Processing Record 47 of Set 6 | wesselsbron
# Processing Record 48 of Set 6 | dawei
# Processing Record 49 of Set 6 | qaqortoq
# Processing Record
# Processing Record 12 of Set 10 | rudnichnyy
# Processing Record 13 of Set 10 | hoemul-li
# Processing Record 14 of Set 10 | gamba
# Processing Record 15 of Set 10 | winnemucca
# Processing Record 16 of Set 10 | kulhudhuffushi
# Processing Record 17 of Set 10 | salaga
# Processing Record 18 of Set 10 | brisas de zicatela
# City not found. Skipping...
# Processing Record 19 of Set 10 | leiyang
# Processing Record 20 of Set 10 | sola
# Processing Record 21 of Set 10 | mawu
# City not found. Skipping...
# Processing Record 22 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 23 of Set 10 | bella vista
# Processing Record 24 of Set 10 | aitape
# Processing Record 25 of Set 10 | leua
# Processing Record 26 of Set 10 | qamdo
# Processing Record 27 of Set 10 | puerto colombia
# Processing Record 28 of Set 10 | yangquan
# Processing Record 29 of Set 10 | kapa'a
# City not found. Skipping...
# Processing Record 30 of Set 10 | hilo
# Processing Record 31 of Set 10 | phaphund
# Processing Record 32 of Set 10 | antsiranana
# Processing Record 33 of Set 10 | zmeinogorsk
# Processing Record 34 of Set 10 | bonthe
# Processing Record 35 of Set 10 | diamantina
# Processing Record 36 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 10 | nishinoomote
# Processing Record 38 of Set 10 | neiafu
# Processing Record 39 of Set 10 | olyokminsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | havre
# Processing Record 41 of Set 10 | campina grande
# Processing Record 42 of Set 10 | norilsk
# Processing Record 43 of Set 10 | sinabang
# Processing Record 44 of Set 10 | suzemka
# Processing Record 45 of Set 10 | nizip
# Processing Record 46 of Set 10 | ingeniero jacobacci
# Processing Record 47 of Set 10 | matam
# Processing Record 48 of Set 10 | bozoum
# Processing Record 49 of Set 10 | greenville
# Processing Record 0 of Set 11 | paros
# Processing Record 1 of Set 11 | kingston
# Processing Record 2 of Set 11 | baruun-urt
# Processing Record 3 of Set 11 | ulsteinvik
# Processing Record 4 of Set 11 | swift current
# Processing Record 5 of Set 11 | saguenay
# Processing Record 6 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 7 of Set 11 | al ghayzah
# Processing Record 8 of Set 11 | san luis de la loma
# City not found. Skipping...
# Processing Record 9 of Set 11 | inhambane
# Processing Record 10 of Set 11 | bandar lampung
# City not found. Skipping...
# Processing Record 11 of Set 11 | valga
# Processing Record 12 of Set 11 | bubaque
# Processing Record 13 of Set 11 | myanaung
# Processing Record 14 of Set 11 | fortuna
# Processing Record 15 of Set 11 | mersing
# Processing Record 16 of Set 11 | ponta delgada
# Processing Record 17 of Set 11 | alenquer
# Processing Record 18 of Set 11 | xilin hot
# Processing Record 19 of Set 11 | santa cruz
# Processing Record 20 of Set 11 | allegan
# Processing Record 21 of Set 11 | murashi
# Processing Record 22 of Set 11 | gorele
# Processing Record 23 of Set 11 | tolanaro
# City not found. Skipping...
# Processing Record 24 of Set 11 | sebastian
# Processing Record 25 of Set 11 | san martin
# Processing Record 26 of Set 11 | tanout
# Processing Record 27 of Set 11 | altai
# Processing Record 28 of Set 11 | syktyvkar
# Processing Record 29 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 30 of Set 11 | khandyga
# Processing Record 31 of Set 11 | kryve ozero
# Processing Record 32 of Set 11 | arar
# Processing Record 33 of Set 11 | yorkton
# Processing Record 34 of Set 11 | homa bay
# Processing Record 35 of Set 11 | cajabamba
# Processing Record 36 of Set 11 | hadagalli
# City not found. Skipping...
# Processing Record 37 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 11 | berdigestyakh
# Processing Record 39 of Set 11 | buritizeiro
# Processing Record 40 of Set 11 | jayapura
# Processing Record 41 of Set 11 | ijuw
# City not found. Skipping...
# Processing Record 42 of Set 11 | ad dawadimi
# Processing Record 43 of Set 11 | kiunga
# Processing Record 44 of Set 11 | bokovskaya
# Processing Record 45 of Set 11 | jiangyou
# Processing Record 46 of Set 11 | sittwe
# Processing Record 47 of Set 11 | itarsi
# Processing Record 48 of Set 11 | taman rajawali
# City not found. Skipping...
# Processing Record 49 of Set 11 | upington
# Processing Record 0 of Set 12 | papao
# Processing Record 1 of Set 12 | san julian
# Processing Record 2 of Set 12 | chokwe
# Processing Record 3 of Set 12 | san antonio de pale
# City not found. Skipping...
# Processing Record 4 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 5 of Set 12 | gaiman
# Processing Record 6 of Set 12 | muzayri'
# City not found. Skipping...
# Processing Record 7 of Set 12 | flin flon
# Processing Record 8 of Set 12 | gadani
# Processing Record 9 of Set 12 | ingeniero guillermo n. juarez
# Processing Record 10 of Set 12 | boonville
# Processing Record 11 of Set 12 | natal
# Processing Record 12 of Set 12 | altay
# Processing Record 13 of Set 12 | hatogaya-honcho
# City not found. Skipping...
# Processing Record 14 of Set 12 | nantucket
# Processing Record 15 of Set 12 | remire-montjoly
# Processing Record 16 of Set 12 | ulaangom
# Processing Record 17 of Set 12 | barra do garcas
# Processing Record 18 of Set 12 | bintulu
# Processing Record 19 of Set 12 | horta
# Processing Record 20 of Set 12 | rongelap
# Processing Record 21 of Set 12 | sumenep
# Processing Record 22 of Set 12 | the pas
# Processing Record 23 of Set 12 | sidi ifni
# Processing Record 24 of Set 12 | urucara
# Processing Record 25 of Set 12 | dambulla
# Processing Record 26 of Set 12 | cabedelo
# Processing Record 27 of Set 12 | kyzyl-suu
# City not found. Skipping...
# Processing Record 28 of Set 12 | ceeldheer
# Processing Record 29 of Set 12 | khuzdar
# Processing Record 30 of Set 12 | chardara
# City not found. Skipping...
# Processing Record 31 of Set 12 | linkou
# Processing Record 32 of Set 12 | gazli
# Processing Record 33 of Set 12 | pangody
# Processing Record 34 of Set 12 | oral
# Processing Record 35 of Set 12 | lame
# Processing Record 36 of Set 12 | lulea
# Processing Record 37 of Set 12 | lapai
# Processing Record 38 of Set 12 | shimoda
# Processing Record 39 of Set 12 | ibanda
# City not found. Skipping...
# Processing Record 40 of Set 12 | caiaponia
# Processing Record 41 of Set 12 | port blair
# Processing Record 42 of Set 12 | christchurch
# Processing Record 43 of Set 12 | xai-xai
# Processing Record 44 of Set 12 | salinopolis
# Processing Record 45 of Set 12 | thulamahashi
# Processing Record 46 of Set 12 | bandarbeyla
# Processing Record 47 of Set 12 | voi
# Processing Record 48 of Set 12 | atherton
# Processing Record 49 of Set 12 | xiangxiang
# Processing Record 0 of Set 13 | callao
# Processing Record 1 of Set 13 | wewak
# Processing Record 2 of Set 13 | anak
# Processing Record 3 of Set 13 | luganville
# Processing Record 4 of Set 13 | lionel town
# Processing Record 5 of Set 13 | pelabuhanratu
# Processing Record 6 of Set 13 | usevia
# Processing Record 7 of Set 13 | sao felix do xingu
# Processing Record 8 of Set 13 | markovo
# Processing Record 9 of Set 13 | soe
# Processing Record 10 of Set 13 | turpan
# Processing Record 11 of Set 13 | vila velha
# Processing Record 12 of Set 13 | pechora
# Processing Record 13 of Set 13 | aiquile
# Processing Record 14 of Set 13 | carolina beach
# Processing Record 15 of Set 13 | plessisville
# Processing Record 16 of Set 13 | zag
# City not found. Skipping...
# Processing Record 17 of Set 13 | chamical
# Processing Record 18 of Set 13 | cape coast
# Processing Record 19 of Set 13 | hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               bethel  41.3712  -73.4140     10.76        89         100
# 1         invercargill -46.4000  168.3500      9.45        62          65
# 2              ushuaia -54.8000  -68.3000      2.81        93         100
# 3              madaoua  14.0730    5.9600     29.38        19           0
# 4        port mathurin -19.6833   63.4167     26.25        60           1
#
#          Wind Speed Country        Date
# City_ID
# 0              0.45      US  1714967521
# 1              4.47      NZ  1714967522
# 2              5.14      AR  1714967522
# 3              3.17      NE  1714967523
# 4              8.86      MU  1714967523

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               bethel  41.3712  -73.4140     10.76        89         100
# 1         invercargill -46.4000  168.3500      9.45        62          65
# 2              ushuaia -54.8000  -68.3000      2.81        93         100
# 3              madaoua  14.0730    5.9600     29.38        19           0
# 4        port mathurin -19.6833   63.4167     26.25        60           1
#
#          Wind Speed Country        Date
# City_ID
# 0              0.45      US  1714967521
# 1              4.47      NZ  1714967522
# 2              5.14      AR  1714967522
# 3              3.17      NE  1714967523
# 4              8.86      MU  1714967523

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Latitude vs. Tempurature (May 8, 2024)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperatures (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Humidity (May 8, 2024)")
plt.xlabel("City Latitudes")
plt.ylabel("Humidity (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Cloudiness (May 8, 2024)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Wind Speed (May 8, 2024)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def lr_plot(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regression = x_value * slope + intercept
    
    
    line_eq = ' y = ' + str(round(slope,2)) + ' x + ' + str(round(intercept,2)) #format on how equation writtten
    
    plt.scatter(x_value, y_value, marker='o') #, edgecolors='black')
    plt.plot(x_value, regression, color='red', linewidth=3) #plot line
    plt.annotate(line_eq, text_coordinates, fontsize=16, color="red") #is the equation text
    plt.grid(True)
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]
# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         bethel  41.3712  -73.4140     10.76        89         100
# 3        madaoua  14.0730    5.9600     29.38        19           0
# 5        tindouf  27.6711   -8.1474     22.25        21           0
# 8         aykhal  66.0000  111.5000      0.02        94         100
# 9        matoury   4.8483  -52.3317     25.98       100          75
#
#          Wind Speed Country        Date
# City_ID
# 0              0.45      US  1714967521
# 3              3.17      NE  1714967523
# 5              4.63      DZ  1714967523
# 8              5.01      RU  1714967524
# 9              1.54      GF  1714967524

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]
# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         invercargill -46.4000  168.3500      9.45        62          65
# 2              ushuaia -54.8000  -68.3000      2.81        93         100
# 4        port mathurin -19.6833   63.4167     26.25        60           1
# 6             lorengau  -2.0226  147.2712     29.54        77         100
# 7            grytviken -54.2811  -36.5092      1.95        84          37
#
#          Wind Speed Country        Date
# City_ID
# 1              4.47      NZ  1714967522
# 2              5.14      AR  1714967522
# 4              8.86      MU  1714967523
# 6              4.26      PG  1714967523
# 7              2.73      GS  1714967524

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Max Temp']
xc = 0
yc = 1

lr_plot(x_value , y_value , "Max Temp" , (6,-10))
plt.title("Northern Temperature vs. Latitude")
#plt.xlabel("Latitude")
#plt.ylabel("Max Temp")
#lt.show()
# Out:
# The r-value is: -0.8687938146843023
# Text(0.5, 1.0, 'Northern Temperature vs. Latitude')

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Max Temp']

lr_plot(x_value , y_value , "Max Temp" , (-30,5))

plt.title("Southern Temperature vs. Latitude")
#plt.xlabel("Latitude")
#plt.ylabel("Max Temp")
#plt.show()
# Out:
# The r-value is: 0.7318007987298578
# Text(0.5, 1.0, 'Southern Temperature vs. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# The analysis of both charts reveals a compelling correlation between latitude and temperature. As we approach the equator (0° latitude), there's a noticeable uptick in temperature, indicating a direct relationship. This observation strongly aligns with the hypothesis asserting that regions closer to the equator experience higher temperatures compared to those near the poles. This correlation is bolstered by a robust r-value, typically hovering around 0.7, indicating a significant statistical relationship between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Humidity']
lr_plot(x_value , y_value , "Humidity" , (45,9))

plt.title("Northern Humidity vs. Latitude")
#plt.xlabel("Latitude")
#plt.ylabel("Humidity")
#plt.show()
# Out:
# The r-value is: 0.08598450372010721
# Text(0.5, 1.0, 'Northern Humidity vs. Latitude')

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Humidity']
lr_plot(x_value , y_value , "Humidity" , (-55,30))
plt.title("Southern Humidity vs. Latitude")
# Out:
# The r-value is: 0.27385658212612046
# Text(0.5, 1.0, 'Southern Humidity vs. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# After carefully examining both charts, it becomes apparent that there's essentially no discernible correlation between humidity and latitude. Regardless of whether we're looking at Northern or Southern latitudes, the linear regression remains slightly flat, indicating a consistent level of humidity across different regions. This consistency is reinforced by the low r-values observed in both charts, suggesting that latitude has little influence on humidity levels. In essence, latitude seems to have minimal impact on humidity, with variations in other factors likely playing a more significant role in determining moisture levels across different latitudes.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Cloudiness']
lr_plot(x_value , y_value , "Cloudiness" , (50,25))
plt.title("Northern Cloudiness vs. Latitude")
# Out:
# The r-value is: 0.10668946588823405
# Text(0.5, 1.0, 'Northern Cloudiness vs. Latitude')

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Cloudiness']

lr_plot(x_value , y_value , "Cloudiness" , (-30,5))
plt.title("Southern Cloudiness vs. Latitude")
# Out:
# The r-value is: 0.1616073431298417
# Text(0.5, 1.0, 'Southern Cloudiness vs. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Upon close examination, it becomes evident that there's essentially no discernible relationship between cloud cover and latitude. Regardless of the latitude considered, cloud cover appears to occur across the spectrum, varying from complete absence to full coverage (0 to 100). The flat linear regression line further reinforces this observation, indicating that latitude doesn't significantly influence cloud cover. This conclusion is supported by the r-value, which hovers close to zero, suggesting that changes in latitude have little impact on the occurrence or extent of cloud cover. In essence, cloud cover seems to be influenced by factors other than latitude, with diverse atmospheric dynamics at play across different regions.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Wind Speed']
lr_plot(x_value , y_value , "Wind Speed" , (0,12))
plt.title("Northern Wind Speed vs. Latitude")
# Out:
# The r-value is: 0.02348784108776627
# Text(0.5, 1.0, 'Northern Wind Speed vs. Latitude')

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Wind Speed']

lr_plot(x_value , y_value , "Wind sSpeed" , (-40,12))
plt.title("Southern Wind Speed vs. Latitude")
# Out:
# The r-value is: -0.21582728375321636
# Text(0.5, 1.0, 'Southern Wind Speed vs. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Exploring the connection between wind speed and latitude unveils a somewhat intricate scenario, differing between the hemispheres. In the Northern Hemisphere, the linear regression line remains flat, indicating no significant correlation between wind speed and latitude. Conversely, in the Southern Hemisphere, a subtle trend emerges, with wind speed exhibiting a slight decrease as it approaches the equator.
# However, this decline is minimal, typically hovering around 7-8 f/s, and is accompanied by a low r-value, indicating a weak correlation at best. In essence, while there's a nuanced pattern in the Southern Hemisphere, the overall relationship between wind speed and latitude appears to be relatively weak and influenced by various other factors.
