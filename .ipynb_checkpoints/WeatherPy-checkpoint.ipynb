# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1550)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1550)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q= + {city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | ancud
# Processing Record 3 of Set 1 | sumbe
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | atafu village
# Processing Record 9 of Set 1 | udachny
# City not found. Skipping...
# Processing Record 10 of Set 1 | olonkinbyen
# Processing Record 11 of Set 1 | san jose del cabo
# Processing Record 12 of Set 1 | la passe
# City not found. Skipping...
# Processing Record 13 of Set 1 | pangoa
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | kerikeri
# Processing Record 16 of Set 1 | bilibino
# Processing Record 17 of Set 1 | leh
# Processing Record 18 of Set 1 | hamilton
# Processing Record 19 of Set 1 | kota kinabalu
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | kasane
# Processing Record 22 of Set 1 | anadyr
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | colonia
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | valparaiso
# Processing Record 27 of Set 1 | cole harbour
# Processing Record 28 of Set 1 | mount isa
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | roma
# Processing Record 31 of Set 1 | point pedro
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 1 | san julian
# Processing Record 36 of Set 1 | grytviken
# Processing Record 37 of Set 1 | friedeburg
# Processing Record 38 of Set 1 | mao
# Processing Record 39 of Set 1 | antsiranana
# Processing Record 40 of Set 1 | ende
# Processing Record 41 of Set 1 | waitangi
# Processing Record 42 of Set 1 | panama city beach
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | salavan
# Processing Record 45 of Set 1 | pontianak
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | port augusta
# Processing Record 48 of Set 1 | isafjordur
# City not found. Skipping...
# Processing Record 49 of Set 1 | port mathurin
# Processing Record 50 of Set 1 | hasaki
# Processing Record 0 of Set 2 | remire-montjoly
# Processing Record 1 of Set 2 | nuriootpa
# Processing Record 2 of Set 2 | lihue
# Processing Record 3 of Set 2 | nova sintra
# City not found. Skipping...
# Processing Record 4 of Set 2 | west island
# Processing Record 5 of Set 2 | college
# Processing Record 6 of Set 2 | piacabucu
# Processing Record 7 of Set 2 | kaiapoi
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | nantucket
# Processing Record 10 of Set 2 | bubaque
# Processing Record 11 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 2 | carbonear
# Processing Record 13 of Set 2 | puerto natales
# Processing Record 14 of Set 2 | sao vicente
# Processing Record 15 of Set 2 | blackmans bay
# Processing Record 16 of Set 2 | papatowai
# City not found. Skipping...
# Processing Record 17 of Set 2 | nadym
# Processing Record 18 of Set 2 | invercargill
# Processing Record 19 of Set 2 | keflavik
# Processing Record 20 of Set 2 | balqash
# Processing Record 21 of Set 2 | margaret river
# Processing Record 22 of Set 2 | qarauyl
# Processing Record 23 of Set 2 | hood river
# Processing Record 24 of Set 2 | nemuro
# Processing Record 25 of Set 2 | genhe
# Processing Record 26 of Set 2 | altai
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | vila velha
# Processing Record 3 of Set 4 | kinablangan
# Processing Record 4 of Set 4 | mahina
# Processing Record 5 of Set 4 | laizhou
# City not found. Skipping...
# Processing Record 6 of Set 4 | mossel bay
# Processing Record 7 of Set 4 | kolosovka
# Processing Record 8 of Set 4 | puerto ayora
# Processing Record 9 of Set 4 | mersa matruh
# City not found. Skipping...
# Processing Record 10 of Set 4 | vorgashor
# Processing Record 11 of Set 4 | flying fish cove
# Processing Record 12 of Set 4 | ambon
# Processing Record 13 of Set 4 | sao pedro do sul
# Processing Record 14 of Set 4 | lompoc
# Processing Record 15 of Set 4 | west bay
# Processing Record 16 of Set 4 | urangan
# Processing Record 17 of Set 4 | crane
# Processing Record 18 of Set 4 | igarka
# Processing Record 19 of Set 4 | bor
# Processing Record 20 of Set 4 | hoi an
# Processing Record 21 of Set 4 | haimen
# Processing Record 22 of Set 4 | monze
# Processing Record 23 of Set 4 | berberati
# Processing Record 24 of Set 4 | paulinia
# Processing Record 25 of Set 4 | kailua-kona
# Processing Record 26 of Set 4 | wailua homesteads
# Processing Record 27 of Set 4 | korsakov
# Processing Record 28 of Set 4 | revda
# Processing Record 29 of Set 4 | noshiro
# Processing Record 30 of Set 4 | klyuchi
# Processing Record 31 of Set 4 | port blair
# Processing Record 32 of Set 4 | portland
# Processing Record 33 of Set 4 | la ronge
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | champerico
# Processing Record 36 of Set 4 | alice springs
# Processing Record 37 of Set 4 | thunder bay
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | betioky
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | villa gesell
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | nizhniy kuranakh
# Processing Record 45 of Set 4 | rampur
# Processing Record 46 of Set 4 | singkil
# City not found. Skipping...
# Processing Record 47 of Set 4 | island harbour
# City not found. Skipping...
# Processing Record 48 of Set 4 | arauquita
# Processing Record 49 of Set 4 | san juan del sur
# Processing Record 0 of Set 5 | hithadhoo
# Processing Record 1 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 2 of Set 5 | quellon
# City not found. Skipping...
# Processing Record 3 of Set 5 | borogontsy
# Processing Record 4 of Set 5 | burang
# Processing Record 5 of Set 5 | payyannur
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | al hamul
# Processing Record 8 of Set 5 | ambovombe
# Processing Record 9 of Set 5 | fonadhoo
# City not found. Skipping...
# Processing Record 10 of Set 5 | badger
# Processing Record 11 of Set 5 | maragogi
# Processing Record 12 of Set 5 | arauca
# Processing Record 13 of Set 5 | manavalakurichi
# Processing Record 14 of Set 5 | mana
# Processing Record 15 of Set 5 | ellsworth
# Processing Record 16 of Set 5 | solnechnyy
# Processing Record 17 of Set 5 | whitecourt
# Processing Record 18 of Set 5 | betio village
# Processing Record 19 of Set 5 | baiao
# Processing Record 20 of Set 5 | lata
# Processing Record 21 of Set 5 | port lincoln
# Processing Record 22 of Set 5 | aljezur
# Processing Record 23 of Set 5 | boise
# Processing Record 24 of Set 5 | xiangtan
# Processing Record 25 of Set 5 | mount pearl
# Processing Record 26 of Set 5 | fort bragg
# Processing Record 27 of Set 5 | san antonio de pale
# City not found. Skipping...
# Processing Record 28 of Set 5 | port saint john's
# City not found. Skipping...
# Processing Record 29 of Set 5 | smithers
# Processing Record 30 of Set 5 | iskateley
# Processing Record 31 of Set 5 | tazacorte
# Processing Record 32 of Set 5 | onguday
# Processing Record 33 of Set 5 | dudinka
# Processing Record 34 of Set 5 | phek
# Processing Record 35 of Set 5 | haiku-pauwela
# Processing Record 36 of Set 5 | narasannapeta
# Processing Record 37 of Set 5 | larkird
# Processing Record 38 of Set 5 | nago
# Processing Record 39 of Set 5 | ghazni
# Processing Record 40 of Set 5 | nar'yan-mar
# City not found. Skipping...
# Processing Record 41 of Set 5 | puerto el triunfo
# Processing Record 42 of Set 5 | pimentel
# Processing Record 43 of Set 5 | wynyard
# Processing Record 44 of Set 5 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 45 of Set 5 | georgetown
# Processing Record 46 of Set 5 | toktogul
# Processing Record 47 of Set 5 | tabora
# Processing Record 48 of Set 5 | usinsk
# Processing Record 49 of Set 5 | kuanda
# Processing Record 0 of Set 6 | howard springs
# City not found. Skipping...
# Processing Record 1 of Set 6 | novodvinsk
# Processing Record 2 of Set 6 | preobrazheniye
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | tura
# Processing Record 5 of Set 6 | shakawe
# Processing Record 6 of Set 6 | lazaro cardenas
# Processing Record 7 of Set 6 | broken hill
# Processing Record 8 of Set 6 | jianshui
# City not found. Skipping...
# Processing Record 9 of Set 6 | katsuren-haebaru
# City not found. Skipping...
# Processing Record 10 of Set 6 | bazarak
# Processing Record 11 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 12 of Set 6 | rio grande
# Processing Record 13 of Set 6 | bosaso
# City not found. Skipping...
# Processing Record 14 of Set 6 | lodja
# Processing Record 15 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 16 of Set 6 | kharkhorin
# Processing Record 17 of Set 6 | mccook
# Processing Record 18 of Set 6 | midland
# Processing Record 19 of Set 6 | mitsamiouli
# Processing Record 20 of Set 6 | walvis bay
# Processing Record 21 of Set 6 | balabac
# Processing Record 22 of Set 6 | azul
# Processing Record 23 of Set 6 | arthur's town
# City not found. Skipping...
# Processing Record 24 of Set 6 | sihanoukville
# Processing Record 25 of Set 6 | agat village
# Processing Record 26 of Set 6 | rabaul
# Processing Record 27 of Set 6 | sorsk
# Processing Record 28 of Set 6 | arraial do cabo
# Processing Record 29 of Set 6 | shitanjing
# Processing Record 30 of Set 6 | karratha
# Processing Record 31 of Set 6 | mulanur
# Processing Record 32 of Set 6 | bikenibeu village
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | chui
# Processing Record 36 of Set 6 | rabah
# Processing Record 37 of Set 6 | kuala belait
# Processing Record 38 of Set 6 | cacheu
# Processing Record 39 of Set 6 | cuatro cienegas de carranza
# City not found. Skipping...
# Processing Record 40 of Set 6 | maihar
# Processing Record 41 of Set 6 | vorkuta
# Processing Record 42 of Set 6 | luderitz
# Processing Record 43 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record
# Processing Record 31 of Set 9 | miracema do tocantins
# City not found. Skipping...
# Processing Record 32 of Set 9 | kismayo
# City not found. Skipping...
# Processing Record 33 of Set 9 | douz
# Processing Record 34 of Set 9 | st. john's
# City not found. Skipping...
# Processing Record 35 of Set 9 | puerto lempira
# Processing Record 36 of Set 9 | hami
# Processing Record 37 of Set 9 | yuzhno-kurilsk
# Processing Record 38 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 39 of Set 9 | sona
# Processing Record 40 of Set 9 | ballina
# Processing Record 41 of Set 9 | saipan
# Processing Record 42 of Set 9 | galliano
# Processing Record 43 of Set 9 | necochea
# Processing Record 44 of Set 9 | qaqortoq
# Processing Record 45 of Set 9 | tazovsky
# City not found. Skipping...
# Processing Record 46 of Set 9 | freetown
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | holualoa
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 0 of Set 10 | touros
# Processing Record 1 of Set 10 | constantia
# Processing Record 2 of Set 10 | matoury
# Processing Record 3 of Set 10 | basco
# Processing Record 4 of Set 10 | ugoofaaru
# Processing Record 5 of Set 10 | kapa'a
# City not found. Skipping...
# Processing Record 6 of Set 10 | shangzhi
# Processing Record 7 of Set 10 | as sulayyil
# Processing Record 8 of Set 10 | kemin
# City not found. Skipping...
# Processing Record 9 of Set 10 | ust-nera
# Processing Record 10 of Set 10 | aqsay
# Processing Record 11 of Set 10 | flin flon
# Processing Record 12 of Set 10 | hailey
# Processing Record 13 of Set 10 | pebble creek
# Processing Record 14 of Set 10 | bloemhof
# Processing Record 15 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 10 | conceicao da barra
# Processing Record 17 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 18 of Set 10 | jieshou
# Processing Record 19 of Set 10 | martapura
# Processing Record 20 of Set 10 | cidreira
# Processing Record 21 of Set 10 | manokwari
# Processing Record 22 of Set 10 | timbuktu
# Processing Record 23 of Set 10 | the bottom
# Processing Record 24 of Set 10 | el nido
# Processing Record 25 of Set 10 | ushtobe
# City not found. Skipping...
# Processing Record 26 of Set 10 | halden
# Processing Record 27 of Set 10 | goondiwindi
# Processing Record 28 of Set 10 | nuuk
# Processing Record 29 of Set 10 | mabaruma
# Processing Record 30 of Set 10 | anabar
# City not found. Skipping...
# Processing Record 31 of Set 10 | valle vista
# Processing Record 32 of Set 10 | kingston
# Processing Record 33 of Set 10 | suntar
# Processing Record 34 of Set 10 | chibougamau
# Processing Record 35 of Set 10 | carutapera
# Processing Record 36 of Set 10 | gadzhiyevo
# Processing Record 37 of Set 10 | chatillon-sur-seine
# Processing Record 38 of Set 10 | tsiombe
# Processing Record 39 of Set 10 | palmas de monte alto
# Processing Record 40 of Set 10 | machico
# Processing Record 41 of Set 10 | inhambane
# Processing Record 42 of Set 10 | khandyga
# Processing Record 43 of Set 10 | peace river
# Processing Record 44 of Set 10 | cape coast
# Processing Record 45 of Set 10 | bandarbeyla
# Processing Record 46 of Set 10 | estevan
# Processing Record 47 of Set 10 | quetta
# Processing Record 48 of Set 10 | shahba
# Processing Record 49 of Set 10 | jincheng
# Processing Record 0 of Set 11 | kabarnet
# Processing Record 1 of Set 11 | bijar
# Processing Record 2 of Set 11 | aoulef
# Processing Record 3 of Set 11 | tamanrasset
# Processing Record 4 of Set 11 | cuyo
# Processing Record 5 of Set 11 | fale old settlement
# Processing Record 6 of Set 11 | tongchuanshi
# City not found. Skipping...
# Processing Record 7 of Set 11 | santana do acarau
# Processing Record 8 of Set 11 | tabou
# Processing Record 9 of Set 11 | devils lake
# Processing Record 10 of Set 11 | urzhar
# Processing Record 11 of Set 11 | el calafate
# Processing Record 12 of Set 11 | sedziszow
# Processing Record 13 of Set 11 | aitape
# Processing Record 14 of Set 11 | zhumysker
# Processing Record 15 of Set 11 | belyayevka
# Processing Record 16 of Set 11 | minas de marcona
# Processing Record 17 of Set 11 | yalihuyuk
# Processing Record 18 of Set 11 | ocean shores
# Processing Record 19 of Set 11 | chashniki
# Processing Record 20 of Set 11 | san rafael
# Processing Record 21 of Set 11 | berdigestyakh
# Processing Record 22 of Set 11 | corralillo
# Processing Record 23 of Set 11 | astrakhan
# Processing Record 24 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 25 of Set 11 | vodice
# Processing Record 26 of Set 11 | papao
# Processing Record 27 of Set 11 | adler
# Processing Record 28 of Set 11 | auki
# Processing Record 29 of Set 11 | morehead city
# Processing Record 30 of Set 11 | gornopravdinsk
# Processing Record 31 of Set 11 | darwin
# Processing Record 32 of Set 11 | sarangani
# Processing Record 33 of Set 11 | la mana
# Processing Record 34 of Set 11 | port moresby
# Processing Record 35 of Set 11 | nyala
# Processing Record 36 of Set 11 | idrinskoye
# Processing Record 37 of Set 11 | sola
# Processing Record 38 of Set 11 | kyren
# Processing Record 39 of Set 11 | la'ie
# City not found. Skipping...
# Processing Record 40 of Set 11 | isangel
# Processing Record 41 of Set 11 | miches
# Processing Record 42 of Set 11 | richards bay
# Processing Record 43 of Set 11 | jinka
# Processing Record 44 of Set 11 | ust-tsilma
# Processing Record 45 of Set 11 | campo gallo
# Processing Record 46 of Set 11 | sylvan lake
# Processing Record 47 of Set 11 | sayansk
# Processing Record 48 of Set 11 | la isla
# Processing Record 49 of Set 11 | koundara
# Processing Record 0 of Set 12 | luanda
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | dourbali
# Processing Record 3 of Set 12 | sao tome
# Processing Record 4 of Set 12 | ormara
# Processing Record 5 of Set 12 | chinde
# City not found. Skipping...
# Processing Record 6 of Set 12 | najran
# Processing Record 7 of Set 12 | hadibu
# City not found. Skipping...
# Processing Record 8 of Set 12 | kupang
# Processing Record 9 of Set 12 | susuman
# Processing Record 10 of Set 12 | port-vila
# Processing Record 11 of Set 12 | cidade velha
# Processing Record 12 of Set 12 | paraguacu
# Processing Record 13 of Set 12 | prainha
# Processing Record 14 of Set 12 | merizo village
# Processing Record 15 of Set 12 | tshikapa
# Processing Record 16 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 17 of Set 12 | ola
# Processing Record 18 of Set 12 | san matias
# Processing Record 19 of Set 12 | dryden
# Processing Record 20 of Set 12 | dunay
# Processing Record 21 of Set 12 | edinburg
# Processing Record 22 of Set 12 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 23 of Set 12 | la porte
# Processing Record 24 of Set 12 | palmas
# Processing Record 25 of Set 12 | cadale
# Processing Record 26 of Set 12 | hun
# Processing Record 27 of Set 12 | fort mcmurray
# Processing Record 28 of Set 12 | mandeure
# Processing Record 29 of Set 12 | sergeyevka
# Processing Record 30 of Set 12 | paita
# Processing Record 31 of Set 12 | ust'-charyshskaya pristan'
# City not found. Skipping...
# Processing Record 32 of Set 12 | fada n'gourma
# City not found. Skipping...
# Processing Record 33 of Set 12 | veraval
# Processing Record 34 of Set 12 | dubbo
# Processing Record 35 of Set 12 | grantsville
# Processing Record 36 of Set 12 | tual
# Processing Record 37 of Set 12 | charters towers
# Processing Record 38 of Set 12 | belmar
# Processing Record 39 of Set 12 | jayapura
# Processing Record 40 of Set 12 | conduaga
# Processing Record 41 of Set 12 | raahe
# Processing Record 42 of Set 12 | rikaze
# Processing Record 43 of Set 12 | howrah
# Processing Record 44 of Set 12 | ujae
# Processing Record 45 of Set 12 | kalabo
# Processing Record 46 of Set 12 | santaquin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          524
# Lat           524
# Lng           524
# Max Temp      524
# Humidity      524
# Cloudiness    524
# Wind Speed    524
# Country       524
# Date          524
# dtype: int64

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({ "City": cities,
                              "Lat": city_lat, 
                              "Lng": city_lng, 
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date
                            })

# Convert unix numbers in date column to readable datetime
city_data_df["Date"] = pd.to_datetime(city_data_df["Date"] , unit = "s")

# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  adamstown  39.9755 -111.7852      7.87        61         100        3.13
# 1      ancud  39.9755 -111.7852      7.87        61         100        3.13
# 2      sumbe  39.9755 -111.7852      7.87        61         100        3.13
# 3     bethel  39.9755 -111.7852      7.87        61         100        3.13
# 4     kodiak  39.9755 -111.7852      7.87        61         100        3.13
#
#   Country                Date
# 0      US 2024-05-06 19:56:26
# 1      US 2024-05-06 19:56:26
# 2      US 2024-05-06 19:56:26
# 3      US 2024-05-06 19:56:26
# 4      US 2024-05-06 19:56:26

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Latitude vs. Tempurature (May 8, 2024)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperatures (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Humidity (May 8, 2024)")
plt.xlabel("City Latitudes")
plt.ylabel("Humidity (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Cloudiness (May 8, 2024)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", facecolors="steelblue", edgecolor="black" , alpha=0.75)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Wind Speed (May 8, 2024)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def lr_plot(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regression = x_value * slope + intercept
    
    
    line_eq = ' y = ' + str(round(slope,2)) + ' x + ' + str(round(intercept,2)) #format on how equation writtten
    
    plt.scatter(x_value, y_value, marker='o') #, edgecolors='black')
    plt.plot(x_value, regression, color='red', linewidth=3) #plot line
    plt.annotate(line_eq, text_coordinates, fontsize=16, color="red") #is the equation text
    plt.grid(True)
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]
# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]
# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Max Temp']
xc = 0
yc = 1

lr_plot(x_value , y_value , "Max Temp" , (6,-10))
plt.title("Northern Temperature vs. Latitude")
#plt.xlabel("Latitude")
#plt.ylabel("Max Temp")
#lt.show()

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Max Temp']

lr_plot(x_value , y_value , "Max Temp" , (-30,5))

plt.title("Southern Temperature vs. Latitude")
#plt.xlabel("Latitude")
#plt.ylabel("Max Temp")
#plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# The analysis of both charts reveals a compelling correlation between latitude and temperature. As we approach the equator (0° latitude), there's a noticeable uptick in temperature, indicating a direct relationship. This observation strongly aligns with the hypothesis asserting that regions closer to the equator experience higher temperatures compared to those near the poles. This correlation is bolstered by a robust r-value, typically hovering around 0.7, indicating a significant statistical relationship between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Humidity']
lr_plot(x_value , y_value , "Humidity" , (45,9))

plt.title("Northern Humidity vs. Latitude")
#plt.xlabel("Latitude")
#plt.ylabel("Humidity")
#plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Humidity']
lr_plot(x_value , y_value , "Humidity" , (-55,30))
plt.title("Southern Humidity vs. Latitude")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# After carefully examining both charts, it becomes apparent that there's essentially no discernible correlation between humidity and latitude. Regardless of whether we're looking at Northern or Southern latitudes, the linear regression remains slightly flat, indicating a consistent level of humidity across different regions. This consistency is reinforced by the low r-values observed in both charts, suggesting that latitude has little influence on humidity levels. In essence, latitude seems to have minimal impact on humidity, with variations in other factors likely playing a more significant role in determining moisture levels across different latitudes.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Cloudiness']
lr_plot(x_value , y_value , "Cloudiness" , (50,25))
plt.title("Northern Cloudiness vs. Latitude")

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Cloudiness']

lr_plot(x_value , y_value , "Cloudiness" , (-30,5))
plt.title("Southern Cloudiness vs. Latitude")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Upon close examination, it becomes evident that there's essentially no discernible relationship between cloud cover and latitude. Regardless of the latitude considered, cloud cover appears to occur across the spectrum, varying from complete absence to full coverage (0 to 100). The flat linear regression line further reinforces this observation, indicating that latitude doesn't significantly influence cloud cover. This conclusion is supported by the r-value, which hovers close to zero, suggesting that changes in latitude have little impact on the occurrence or extent of cloud cover. In essence, cloud cover seems to be influenced by factors other than latitude, with diverse atmospheric dynamics at play across different regions.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Wind Speed']
lr_plot(x_value , y_value , "Wind Speed" , (0,12))
plt.title("Northern Wind Speed vs. Latitude")

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Wind Speed']

lr_plot(x_value , y_value , "Wind sSpeed" , (-40,12))
plt.title("Southern Wind Speed vs. Latitude")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Exploring the connection between wind speed and latitude unveils a somewhat intricate scenario, differing between the hemispheres. In the Northern Hemisphere, the linear regression line remains flat, indicating no significant correlation between wind speed and latitude. Conversely, in the Southern Hemisphere, a subtle trend emerges, with wind speed exhibiting a slight decrease as it approaches the equator.
# However, this decline is minimal, typically hovering around 7-8 f/s, and is accompanied by a low r-value, indicating a weak correlation at best. In essence, while there's a nuanced pattern in the Southern Hemisphere, the overall relationship between wind speed and latitude appears to be relatively weak and influenced by various other factors.
